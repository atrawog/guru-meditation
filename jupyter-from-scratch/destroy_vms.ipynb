# %%
import ansible_runner

# Set the desired prefix; defaults to 'd12vm' if not specified
vm_name_prefix = 'k3s-'

# Run the playbook using ansible-runner
result = ansible_runner.run(
    private_data_dir='.',
    playbook='destroy_vms.yml',
    extravars={'vm_name_prefix': vm_name_prefix}
)

# Check the status of the playbook run
if result.rc == 0:
    print("Playbook executed successfully")
else:
    print("Playbook execution failed")
# Out:
# [WARNING]: No inventory was parsed, only implicit localhost is available
# [WARNING]: provided hosts list is empty, only localhost is available. Note that
# the implicit localhost does not match 'all'
#
# PLAY [Delete VMs with a specified name prefix] *********************************
#
# TASK [List all VMs] ************************************************************
# ok: [localhost]
#
# TASK [Display all VMs] *********************************************************
# ok: [localhost] => {
#     "msg": "All VMs: ['Win11', 'k3s-agent1', 'k3s-server1', 'Win11_VFIO_Bazzite', 'k3s-agent2', 'Win11_VFIO']"
# }
#
# TASK [Display vm_name_prefix] **************************************************
# ok: [localhost] => {
#     "msg": "VM name prefix is set to: 'k3s-'"
# }
#
# TASK [Filter VMs with the specified prefix] ************************************
# ok: [localhost]
#
# TASK [Display VMs to delete] ***************************************************
# ok: [localhost] => {
#     "msg": "VMs to delete: ['k3s-agent1', 'k3s-server1', 'k3s-agent2']"
# }
#
# TASK [Destroy VMs] *************************************************************
# changed: [localhost] => (item=k3s-agent1)
# changed: [localhost] => (item=k3s-server1)
# changed: [localhost] => (item=k3s-agent2)
#
# TASK [Undefine VMs with NVRAM] *************************************************
# changed: [localhost] => (item=k3s-agent1)
# changed: [localhost] => (item=k3s-server1)
# changed: [localhost] => (item=k3s-agent2)
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=7    changed=2    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# Playbook executed successfully
